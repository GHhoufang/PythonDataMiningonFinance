# %%
from sklearn.datasets import load_boston
import numpy as np
import pandas as pd
#直接调用load_boston，通过网络读取数据
boston = load_boston()
#数据集分为两部分，其中boston.data是前13个字段的数据
#boston.target中是第14个字段MEDV的大数据
#将其拼接为一个DataFrame对象
col=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']
bostonDF = pd.DataFrame(boston.data, columns=col)
bostonDF['MEDV']=boston.target
print("数据集头5行数据：")
print(bostonDF.head())
# Out:
# 数据集头5行数据：
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#输出14个字段的协方差
print('各属性的协方差：')
bostonDF.cov()
# Out:
# 各属性的协方差：
#                CRIM           ZN       INDUS      CHAS        NOX         RM  \
# CRIM      73.904671   -39.990934   23.854453 -0.120739   0.415924  -1.328491
# ZN       -39.990934   543.936814  -85.412648 -0.252925  -1.396148   5.112513
# INDUS     23.854453   -85.412648   47.064442  0.109669   0.607074  -1.887957
# CHAS      -0.120739    -0.252925    0.109669  0.064513   0.002684   0.016285
# NOX        0.415924    -1.396148    0.607074  0.002684   0.013428  -0.024603
# RM        -1.328491     5.112513   -1.887957  0.016285  -0.024603   0.493671
# AGE       84.886013  -373.901548  124.513903  0.618571   2.385927  -4.751929
# DIS       -6.840937    32.629304  -10.228097 -0.053043  -0.187696   0.303663
# RAD       46.561611   -63.348695   35.549971 -0.016296   0.616929  -1.283815
# TAX      839.717323 -1236.453735  833.360290 -1.523367  13.046286 -34.583448
# PTRATIO    5.364787   -19.776571    5.692104 -0.066819   0.047397  -0.540763
# B       -296.171637   373.721402 -223.579756  1.131325  -4.020570   8.215006
# LSTAT     27.761872   -68.783037   29.580270 -0.097816   0.488946  -3.079741
# MEDV     -30.505977    77.315176  -30.520823  0.409409  -0.455412   4.493446
#
#                  AGE         DIS          RAD           TAX     PTRATIO  \
# CRIM       84.886013   -6.840937    46.561611    839.717323    5.364787
# ZN       -373.901548   32.629304   -63.348695  -1236.453735  -19.776571
# INDUS     124.513903  -10.228097    35.549971    833.360290    5.692104
# CHAS        0.618571   -0.053043    -0.016296     -1.523367   -0.066819
# NOX         2.385927   -0.187696     0.616929     13.046286    0.047397
# RM         -4.751929    0.303663    -1.283815    -34.583448   -0.540763
# AGE       792.358399  -44.329379   111.770846   2402.690122   15.936921
# DIS       -44.329379    4.434015    -9.068252   -189.664592   -1.059775
# RAD       111.770846   -9.068252    75.816366   1335.756577    8.760716
# TAX      2402.690122 -189.664592  1335.756577  28404.759488  168.153141
# PTRATIO    15.936921   -1.059775     8.760716    168.153141    4.686989
# B        -702.940328   56.040356  -353.276219  -6797.911215  -35.059527
# LSTAT     121.077725   -7.473329    30.385442    654.714520    5.782729
# MEDV      -97.589017    4.840229   -30.561228   -726.255716  -10.110657
#
#                    B       LSTAT        MEDV
# CRIM     -296.171637   27.761872  -30.505977
# ZN        373.721402  -68.783037   77.315176
# INDUS    -223.579756   29.580270  -30.520823
# CHAS        1.131325   -0.097816    0.409409
# NOX        -4.020570    0.488946   -0.455412
# RM          8.215006   -3.079741    4.493446
# AGE      -702.940328  121.077725  -97.589017
# DIS        56.040356   -7.473329    4.840229
# RAD      -353.276219   30.385442  -30.561228
# TAX     -6797.911215  654.714520 -726.255716
# PTRATIO   -35.059527    5.782729  -10.110657
# B        8334.752263 -238.667516  279.989834
# LSTAT    -238.667516   50.994760  -48.447538
# MEDV      279.989834  -48.447538   84.586724

# %%
#输出14个字段的相关系数
print('各属性的相关系数：')
bostonDF.corr()
# Out:
# 各属性的相关系数：
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.377365  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.452220 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.385832  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.377904  0.622029  0.579564  0.288250 -0.377365  0.452220 -0.385832
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

#处理Seaborn图表内嵌中文字体问题
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False 
sns.set_style("whitegrid",{'font.sans-serif':['simhei','Arial']})

#观察上一个cell的输出可以发现，和各个属性和价格中位数MEDV的相关系数中
#最大值是和RM的相关系数：0.695360，正的线性相关性最强，
#最小值是和LSTAT的相关系数：-0.737663，负的线性相关性最强，
#通过图形观察RM与LSTAT属性分别与MEDV的相关性
print("观察上一个cell的输出，各个属性和价格中位数MEDV的相关系数中")
print("最大值是和RM的相关系数：0.695360，正的线性相关性最强，")
print("最小值是和LSTAT的相关系数：-0.737663，负的线性相关性最强，")
print("进一步通过图形观察RM与LSTAT属性分别与MEDV的相关性。")
sns.pairplot(bostonDF, x_vars=['RM','LSTAT'], y_vars='MEDV', height=7, aspect=0.8,kind = 'reg')
plt.savefig('ch14_pairplot.png',dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 观察上一个cell的输出，各个属性和价格中位数MEDV的相关系数中
# 最大值是和RM的相关系数：0.695360，正的线性相关性最强，
# 最小值是和LSTAT的相关系数：-0.737663，负的线性相关性最强，
# 进一步通过图形观察RM与LSTAT属性分别与MEDV的相关性。
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#单变量回归分析
print("单变量回归分析")
BostonRM=pd.DataFrame()
#线性回归模型
modelRM = LinearRegression()
modelRM.fit(bostonDF["RM"].values.reshape(-1,1),bostonDF["MEDV"].values.reshape(-1,1))
#intercept为截距
#coef为斜率
print("系数:",modelRM.coef_)
print("截距:",modelRM.intercept_)
print("RM与MEDV的线性回归方程为：")
print("y=%+.4f*x%+.4f" % (modelRM.coef_[0][0],modelRM.intercept_[0]))
print()
modelLSTAT = LinearRegression()
modelLSTAT.fit(bostonDF["LSTAT"].values.reshape(-1,1),bostonDF["MEDV"].values.reshape(-1,1))
print("系数:",modelLSTAT.coef_)
print("截距:",modelLSTAT.intercept_)
print("LSTAT与MEDV的线性回归方程为：")
print("y=%+.4f*x%+.4f" % (modelLSTAT.coef_[0][0],modelLSTAT.intercept_[0]))
# Out:
# 单变量回归分析
# 系数: [[9.10210898]]
# 截距: [-34.67062078]
# RM与MEDV的线性回归方程为：
# y=+9.1021*x-34.6706
#
# 系数: [[-0.95004935]]
# 截距: [34.55384088]
# LSTAT与MEDV的线性回归方程为：
# y=-0.9500*x+34.5538

# %%
#多变量回归分析
print("多变量回归分析")
modelMulti = LinearRegression()
modelMulti.fit(bostonDF[["LSTAT","RM"]].values,bostonDF["MEDV"].values.reshape(-1,1))
print("系数:",modelMulti.coef_)
print("截距:",modelMulti.intercept_)
print("LSTAT与MEDV的线性回归方程为：")
print("y=%+.4f*(LSTAT)%+.4f*(RM)%+.4f" % (modelMulti.coef_[0][0],modelMulti.coef_[0][1],modelMulti.intercept_[0]))
print()
# Out:
# 多变量回归分析
# 系数: [[-0.64235833  5.09478798]]
# 截距: [-1.35827281]
# LSTAT与MEDV的线性回归方程为：
# y=-0.6424*(LSTAT)+5.0948*(RM)-1.3583

# %%
#分析MEDV的数据，根据其1/4分位点的房价数据，
#将整个样本分为贵价房屋和平价房屋
#1/4分位点用于统计描述，是指所有样本中3/4中的数据小于该值
#实际数据集的1/4分位点值为17.02，以小于该值为平价房屋标准
#NormalPrice列的值为0，表示平价；值为1，表示贵价
print(bostonDF["MEDV"].describe())
bostonDF["NormalPrice"]=bostonDF["MEDV"].apply(lambda s:np.float(s>=17.025))
print(bostonDF["NormalPrice"].head())

X = bostonDF.drop(labels=["MEDV","NormalPrice"], axis=1) 
y = bostonDF["NormalPrice"]

#随机抽取90%的样本用于训练
#10%的样本用于测试
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

#均一化数据，将每个训练数据减去其所在列的均值
#处以其所在列的方差，这样改善训练效果
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)

#引入逻辑回归模型
from sklearn import linear_model, datasets

X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test  = pd.DataFrame(scaler.transform(X_test),  columns=X_test.columns)
ExpensiveHouseLR=linear_model.LogisticRegression()
ExpensiveHouseLR.fit(X_train, y_train)
print("系数:",ExpensiveHouseLR.coef_)
print("截距:",ExpensiveHouseLR.intercept_)
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: NormalPrice, dtype: float64
# 系数: [[-0.92164569  0.65126997  0.51493293  0.13653517 -1.21525748 -0.09805405
#   -0.92736533 -0.88089149  0.91338015 -0.72460478 -0.7381216   0.47520731
#   -1.76043042]]
# 截距: [2.73826373]

# %%
#效果评估
print("R值(准确率):",ExpensiveHouseLR.score(X_train, y_train))
# 预测y的值
y_pred = ExpensiveHouseLR.predict(X_test)
#绘制测试集中，真实观测值与模型预测值的图像
x = range(len(X_test))
plt.figure(figsize=(14,7),facecolor="w")
plt.ylim(-0.1,1.5)
plt.axhline(y=0.5, ls='dotted', color='k') 
plt.plot(x,y_test,"ro",marker="*",markersize=16,label="真实值")
plt.plot(x,y_pred,"go",markersize=14,
         label="预测值,$R^2$=%.3f" %ExpensiveHouseLR.score(X_test, y_test),)
plt.legend(loc="upper left")

plt.xlabel("训练集样本编号",fontsize=18)
plt.ylabel("是否平价房屋",fontsize=18)
plt.title("Logistic算法对数据进行分类",fontsize=20)
plt.savefig("ch14_Logistic.png",dpi=300, bbox_inches='tight')
plt.show()
# Out:
# R值(准确率): 0.9340659340659341

# %%
#从ch05_stock_000001.csv读入股票数据，数据文件跨度为2007/12/4-2018/11/30
stockSPDB = pd.read_csv("ch05_stock_000001.csv",encoding = "utf-8")

print("000001股票收盘价5日移动平均：")
#五日移动平均
stockSPDB["5天移动平均"]=stockSPDB["收盘价"].rolling(window=5,center=False).mean()
#输出前10个数据
print(stockSPDB["5天移动平均"].head(10))
#绘图
plt.figure(figsize=(10,4))
plt.plot(stockSPDB["收盘价"],'r-',linewidth=2.0,label="收盘价")
plt.plot(stockSPDB["5天移动平均"],'b:',linewidth=3.0,label="5天移动平均")
plt.xlabel("天",fontsize=18)
plt.ylabel("收盘价",fontsize=18)
plt.legend()
plt.savefig("ch14_Mean01.png",dpi=300,bbox_inches='tight')
plt.show()
# Out:
# 000001股票收盘价5日移动平均：
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4    10.272
# 5    10.264
# 6    10.334
# 7    10.400
# 8    10.478
# 9    10.580
# Name: 5天移动平均, dtype: float64

# %%
#5日指数平滑
#系数a = 2/(n+1)，n为窗口大小,本例为5
print("000001股票收盘价5日指数平滑：")
plt.figure(figsize=(10,4))
plt.plot(stockSPDB["收盘价"],'r-',linewidth=2.0,label="收盘价")
stockSPDB["5天指数平滑"]=stockSPDB["收盘价"].ewm(span=5,min_periods=0,adjust=True,ignore_na=False).mean()
print(stockSPDB["5天指数平滑"].head(10))
plt.plot(stockSPDB["5天指数平滑"],'b:',linewidth=3.0,label="5天指数平滑")
plt.xlabel("天",fontsize=18)
plt.ylabel("收盘价",fontsize=18)
plt.legend()
plt.savefig("ch14_Mean02.png",dpi=300,bbox_inches='tight')
plt.show()
# Out:
# 000001股票收盘价5日指数平滑：
# 0    10.360000
# 1    10.264000
# 2    10.271579
# 3    10.233538
# 4    10.274408
# 5    10.291068
# 6    10.382744
# 7    10.461572
# 8    10.498680
# 9    10.617853
# Name: 5天指数平滑, dtype: float64

# %%
#周期变动分析
print("周期变动分析")
import warnings
import itertools
#导入ARIMA所需包
import statsmodels.api as sm

#以airline_passengers.csv为示例代码数据
#该数据文件是一个按月统计，以千人次为单位的航空旅客数据
df=pd.read_csv('ch14_airline_passengers.csv', index_col='Month', parse_dates=True)
df.dropna(inplace=True)#丢掉缺失的行
df.index=pd.to_datetime(df.index)
print(df.head())
print("原始数据图像:")
df.plot(figsize=(12,6))
plt.savefig("ch14_airpassengers.png",dpi=300,bbox_inches='tight')
# Out:
# 周期变动分析
#             Number in thousands
# Month
# 1949-01-01                112.0
# 1949-02-01                118.0
# 1949-03-01                132.0
# 1949-04-01                129.0
# 1949-05-01                121.0
# 原始数据图像:

# %%
#以下参数来自是下方“(p, d, q)参数选择代码块”的运行结果
#用于设置ARIMA模型的参数
min_order=(3,2,3)
min_seasorder=(3,3,2,12)

# %%
##————————(p, d, q)参数选择代码块————————————————————————————————
##以下代码块用于选择模型参数(p, d, q)
##需要运行数小时甚至数天才能得到结果，供参考
##p：趋势自回归阶数。
##d：趋势差分阶数。
##q：趋势移动平均阶数。
#max = int(len(df)/10)
#p = d = q = range(0, max+1)
#
## Generate all different combinations of p, q and q triplets
#pdq = list(itertools.product(p, d, q))
## Generate all different combinations of seasonal p, q and q triplets
#seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
#
#print('Examples of parameter combinations for Seasonal ARIMA...')
#print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
#print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
#print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
#print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
#
#warnings.filterwarnings("ignore") # specify to ignore warning messages
#aicDF=pd.DataFrame(columns=["pdq","seas_pdq","aic"])
#i=0
#for param in pdq:
#    for param_seasonal in seasonal_pdq:
#        try:
#            mod = sm.tsa.statespace.SARIMAX(df,
#                                            order=param,
#                                            seasonal_order=param_seasonal,
#                                            enforce_stationarity=False,
#                                            enforce_invertibility=False)
#
#            results = mod.fit()
#
#            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
#        except:
#            continue
#        aicDF.loc[i]=[param,param_seasonal,results.aic]
#        i=i+1
#
#print(aicDF.head())
#
##选取得到最小的AIC的(p, d, q)，作为预测的参数
#a=aicDF["aic"].idxmin(axis=0)
#min_order = aicDF.loc[a,"pdq"]
#min_seasorder=aicDF.loc[a,"seas_pdq"]
#print(min_ordre)
#print(min_seasorder)
##———————(p, d, q)参数选择代码块结束—————————————————————————————

# %%
#模型训练
mod = sm.tsa.statespace.SARIMAX(df,
                                order=min_order,
                                seasonal_order=min_seasorder,
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
 
#用训练好的模型验证从1975-01-01开始的数据
pred = results.get_prediction(start=pd.to_datetime('1957-01-01'), dynamic=False)
#输出模型预测数据
print("模型预测的数据：")
print(pred.predicted_mean)
#作图，比较模型拟合数据与真实数据
ax = df['1949':].plot(label='实际值',figsize=(12,6),style='k-')
pred.predicted_mean.plot(ax=ax, label='预测值',style='b:',linewidth=4)

ax.set_xlabel('Date')
ax.set_ylabel('Passenger Number in thousands')
plt.title("周期变动预测",fontsize=18)
plt.legend()
plt.savefig('ch14_sarimax.png',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# C:\Users\houfang\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\houfang\Miniconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\houfang\Miniconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# 模型预测的数据：
# 1957-01-01    315.285925
# 1957-02-01    310.193199
# 1957-03-01    342.972208
# 1957-04-01    343.515998
# 1957-05-01    365.404473
# 1957-06-01    411.150598
# 1957-07-01    464.035832
# 1957-08-01    453.654880
# 1957-09-01    402.558805
# 1957-10-01    338.845989
# 1957-11-01    311.871095
# 1957-12-01    343.392829
# 1958-01-01    347.413326
# 1958-02-01    339.276040
# 1958-03-01    362.110508
# 1958-04-01    341.469195
# 1958-05-01    362.792158
# 1958-06-01    454.971678
# 1958-07-01    486.910074
# 1958-08-01    490.758582
# 1958-09-01    420.921004
# 1958-10-01    350.280650
# 1958-11-01    298.417357
# 1958-12-01    341.944409
# 1959-01-01    349.796784
# 1959-02-01    323.117443
# 1959-03-01    378.380696
# 1959-04-01    384.055402
# 1959-05-01    400.560077
# 1959-06-01    494.039312
# 1959-07-01    543.465395
# 1959-08-01    565.778412
# 1959-09-01    434.740631
# 1959-10-01    407.290828
# 1959-11-01    343.705049
# 1959-12-01    373.460137
# 1960-01-01    420.824016
# 1960-02-01    395.039158
# 1960-03-01    467.897681
# 1960-04-01    429.204824
# 1960-05-01    453.235688
# 1960-06-01    530.494788
# 1960-07-01    622.706412
# 1960-08-01    641.830446
# 1960-09-01    508.344067
# 1960-10-01    447.341387
# 1960-11-01    391.557409
# 1960-12-01    450.897824
# Freq: MS, Name: predicted_mean, dtype: float64
